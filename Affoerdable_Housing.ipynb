# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("c:\\Users\\ADMIN\\Downloads\\my python projects\\Affordable_Housing_by_Town_2011-2022.csv")
df.head()
# Out:
#    Year  Town Code         Town  2010 Census Units  Government Assisted  \
# 0  2020          1      Andover               1317                 18.0
# 1  2020          2      Ansonia               8148                349.0
# 2  2020          3      Ashford               1903                 32.0
# 3  2020          4         Avon               7389                244.0
# 4  2020          5  Barkhamsted               1589                  0.0
#
#    Tenant Rental Assistance   Single Family CHFA/ USDA Mortgages  \
# 0                         1                                   32
# 1                       764                                  147
# 2                         0                                   36
# 3                        16                                   44
# 4                         6                                   23
#
#    Deed Restricted Units  Total Assisted Units  Percent Affordable
# 0                      0                    51                3.87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Year                                 2025 non-null   int64
#  1   Town Code                            2025 non-null   int64
#  2   Town                                 2025 non-null   object
#  3   2010 Census Units                    2025 non-null   int64
#  4   Government Assisted                  2024 non-null   float64
#  5   Tenant Rental Assistance             2025 non-null   int64
#  6    Single Family CHFA/ USDA Mortgages  2025 non-null   int64
#  7   Deed Restricted Units                2025 non-null   int64
#  8   Total Assisted Units                 2025 non-null   int64
#  9   Percent Affordable                   2025 non-null   float64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 158.3+ KB

# %%
df.isnull().sum()
# Out:
# Year                                   0
# Town Code                              0
# Town                                   0
# 2010 Census Units                      0
# Government Assisted                    1
# Tenant Rental Assistance               0
#  Single Family CHFA/ USDA Mortgages    0
# Deed Restricted Units                  0
# Total Assisted Units                   0
# Percent Affordable                     0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df[df['Government Assisted'] == 0]
# Out:
#       Year  Town Code          Town  2010 Census Units  Government Assisted  \
# 4     2020          5   Barkhamsted               1589                  0.0
# 5     2020          6  Beacon Falls               2509                  0.0
# 7     2020          8       Bethany               2044                  0.0
# 11    2020         12        Bolton               2015                  0.0
# 12    2020         13        Bozrah               1059                  0.0
# ...    ...        ...           ...                ...                  ...
# 1989  2022        127       Sherman               1831                  0.0
# 1997  2022        136      Sterling               1511                  0.0
# 2005  2022        145         Union                388                  0.0
# 2008  2022        149        Warren                811                  0.0
# 2014  2022        157        Weston               3674                  0.0
#
# ...

# %%
df = df.drop('Town Code', axis=1)

# %%
df.head()
# Out:
#    Year         Town  2010 Census Units  Government Assisted  \
# 0  2020      Andover               1317                 18.0
# 1  2020      Ansonia               8148                349.0
# 2  2020      Ashford               1903                 32.0
# 3  2020         Avon               7389                244.0
# 4  2020  Barkhamsted               1589                  0.0
#
#    Tenant Rental Assistance   Single Family CHFA/ USDA Mortgages  \
# 0                         1                                   32
# 1                       764                                  147
# 2                         0                                   36
# 3                        16                                   44
# 4                         6                                   23
#
#    Deed Restricted Units  Total Assisted Units  Percent Affordable
# 0                      0                    51                3.87
# 1                      0                  1260               15.46
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Town', '2010 Census Units', 'Government Assisted',
#        'Tenant Rental Assistance', ' Single Family CHFA/ USDA Mortgages',
#        'Deed Restricted Units', 'Total Assisted Units', 'Percent Affordable'],
#       dtype='object')

# %%
sns.scatterplot(x='2010 Census Units',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel='2010 Census Units', ylabel='Percent Affordable'>

# %%
sns.scatterplot(x='Government Assisted',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel='Government Assisted', ylabel='Percent Affordable'>

# %%
sns.scatterplot(x='Tenant Rental Assistance',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel='Tenant Rental Assistance', ylabel='Percent Affordable'>

# %%
sns.scatterplot(x=' Single Family CHFA/ USDA Mortgages',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel=' Single Family CHFA/ USDA Mortgages', ylabel='Percent Affordable'>

# %%
sns.scatterplot(x='Deed Restricted Units',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel='Deed Restricted Units', ylabel='Percent Affordable'>

# %%
sns.scatterplot(x='Total Assisted Units',y='Percent Affordable', data=df, hue='Year')
# Out:
# <Axes: xlabel='Total Assisted Units', ylabel='Percent Affordable'>

# %%
sns.histplot(x="Percent Affordable", bins=20, data=df)
